# %%
#1. write a function which will try to find out len of a string without using an inbuilt len function 
str=input("Enter the String:")

def test1(str):
    count=0
    for i in str:
        count=count+1
    return count
    
print("Length of the String is:",test1(str))
# Out:
# Enter the String:autosaved
# Length of the String is: 9

# %%
#2. write a function which  will be able to print an index of list element without using an index function
l=[1,2,3,4,"sudh","ineuron"]
def test1(li):
    for i in range(0,len(li)):
        print(li[i], ": ", i)
        
test1(l)
# Out:
# 1 :  0
# 2 :  1
# 3 :  2
# 4 :  3
# sudh :  4
# ineuron :  5

# %%
#3. write a function which will be able to print an ip address of your system
import socket

def get_IP():
    host_name = socket.gethostname()
    host_ip=socket.gethostbyname(host_name)
    print("IP Adress of the System :", host_ip)
    
    
get_IP()
# Out:
# IP Adress of the System : 192.168.43.191

# %%
#OR.............
import socket
socket.gethostbyname(socket.gethostname())
# Out:
# '192.168.43.191'

# %%
#4. write a function which will shutdown your system
import os
  
shutdown = input("Do you wish to shutdown your computer ? (yes / no): ")
  
if shutdown == 'no':
    exit()
else:
    os.system("shutdown /s /t 1")
# Out:
# Do you wish to shutdown your computer ? (yes / no): no

# %%
#5. write a function which will take input as a list with any kind of numeric value and give an out as a multiplication of 
#all the numeric data l = [3.5, 6.56, 4,5,"sudh" , "ineuron" , 'fsda bootcamp 2.0']

l = [3.5, 6.56, 4,5,"sudh" , "ineuron" , 'fsda bootcamp 2.0']

def test3(l):
    mul =1
    for i in l:
        if type(i) == int or type(i) == float:
            mul=mul *i
            
    return mul

test3(l)
# Out:
# 459.19999999999993

# %%
#6. write a function which will be able to read all the mails 
import smtplib
import time
import imaplib
import email
ORG_EMAIL = "@gmail.com" 
FROM_EMAIL = 'gentleman7013@gmail.com'
FROM_PWD = 'nqmflpgmgciqanpb'
SMTP_SERVER = "imap.gmail.com" 
SMTP_PORT = 993
imaplib._MAXLINE = 400000000

def read_email_from_gmail():
    try:
        mail = imaplib.IMAP4_SSL(SMTP_SERVER)
        mail.login(FROM_EMAIL,FROM_PWD)
        mail.select('inbox')

        data = mail.search(None, 'ALL')
        mail_ids = data[1]
        id_list = mail_ids[0].split()   
        first_email_id = int(id_list[0])
        latest_email_id = int(id_list[-1])

        for i in range(latest_email_id,first_email_id, -1):
            data = mail.fetch(str(i), '(RFC822)' )
            for response_part in data:
                arr = response_part[0]
                if isinstance(arr, tuple):
                    msg = email.message_from_string(str(arr[1],'utf-8'))
                    email_subject = msg['subject']
                    email_from = msg['from']
                    print('From : ' + email_from + '\n')
                    print('Subject : ' + email_subject + '\n')

    except Exception as e:
        traceback.print_exc() 
        print(str(e))

read_email_from_gmail()
# Out:
# From : Mail Delivery Subsystem <mailer-daemon@googlemail.com>
#
# Subject : Delivery Status Notification (Failure)
#
# From : Mail Delivery Subsystem <mailer-daemon@googlemail.com>
#
# Subject : Delivery Status Notification (Failure)
#
# From : Google <no-reply@accounts.google.com>
#
# Subject : Security alert
#
# From : Google <no-reply@accounts.google.com>
#
# Subject : 2-Step Verification turned on
#
# From : "iNeuron.ai" <contact@ineuron.ai>
#
# Subject : Full Stack Data Science BootCamp 2.0
#
# From : "iNeuron.ai" <contact@ineuron.ai>
#
# Subject : Full Stack Data Science BootCamp 2.0 3 PM IST
#
# From : The Google Account Team <google-noreply@google.com>
#
# Subject : Manjunath, review your Google Account settings
#
# From : Google <no-reply@accounts.google.com>
#
# Subject : Security alert
#
# From : ticketadmin@irctc.co.in
#
# Subject : IRCTC Refund mail
#
# From : Google <no-reply@accounts.google.com>
#
# Subject : Critical security alert
#
# ...

# %%
#7 . write a function which will be able to send a mail to anyone 

import smtplib , ssl
port = 465  # For SSL
smtp_server = "smtp.gmail.com"
sender_email = "gentleman7013@gmail.com"  # Enter your address
receiver_email = "shrinivasnilajagi35@gmail.com"  # Enter receiver address
#password = 'rlplfdcsoiqruagn'
password = 'nqmflpgmgciqanpb'
message = """ Hi Buddy, how are you.... """

context = ssl.create_default_context()
with smtplib.SMTP_SSL(smtp_server, port, context=context) as server:
    server.login(sender_email, password)
    server.sendmail(sender_email, receiver_email, message)

# %%
pip install docx2txt
# Out:
# ...
#   Created wheel for docx2txt: filename=docx2txt-0.8-py3-none-any.whl size=3980 sha256=87e5654e532d79f6c8425c94dcd831aa387bc8fefb2a60012da98029d1b05f3b
#   Stored in directory: c:\users\home\appdata\local\pip\cache\wheels\40\75\01\e6c444034338bde9c7947d3467807f889123465c2371e77418
# Successfully built docx2txt
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#8. write a function which will be able to read a doc/word file from your system 
import docx2txt
docx2txt.process('D:/Ineuron/demo.docx')
# Out:
# '#7 . write a function which will be able to send a mail to anyone \n\n\n\nimport smtplib , ssl\n\nport = 465  # For SSL\n\nsmtp_server = "smtp.gmail.com"\n\nsender_email = "gentleman7013@gmail.com"  # Enter your address\n\nreceiver_email = "shrinivasnilajagi35@gmail.com"  # Enter receiver address\n\n#password = \'rlplfdcsoiqruagn\'\n\npassword = \'nqmflpgmgciqanpb\'\n\nmessage = """ Hi Buddy, how are you.... """\n\n\n\ncontext = ssl.create_default_context()\n\nwith smtplib.SMTP_SSL(smtp_server, port, context=context) as server:\n\n    server.login(sender_email, password)\n\n    server.sendmail(sender_email, receiver_email, message)'
